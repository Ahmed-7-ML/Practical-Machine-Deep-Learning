# %%
import pandas as pd
import numpy as np

# %%
labels = ['a', 'b', 'c', 'd']

data = [14, 42, 32, 41]

arr = np.array(data)

d = {'a':10, 'b':20, 'c':30}

# %% [markdown]
# ## Series

# %%
s1 = pd.Series(data= data,  index= labels)

# %%
s1
# Out:
# a    14
# b    42
# c    32
# d    41
# dtype: int64

# %%
s2 = pd.Series(data= d)
# Keys-> Index Labels
# Values -> Values of Series

# %%
s2
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s1 +s2
# Out:
# a    24.0
# b    62.0
# c    62.0
# d     NaN
# dtype: float64

# %% [markdown]
# ## DataFrame

# %%
df = pd.DataFrame(np.random.randn(5, 4), index=['a', 'b', 'c', 'd', 'e'], columns=['Egy','US', 'UK', 'Jap'])

# %%
df
# Out:
#         Egy        US        UK       Jap
# a  0.648428  0.330946 -1.780938  0.085884
# b -1.252430  0.253275 -1.254233 -1.570334
# c -0.479003 -0.761110 -0.427035 -0.112740
# d -0.221216 -1.529028  1.094876  0.331932
# e  1.100920  0.799423  0.529076 -0.620295
