# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow 
from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential

# %%
df = pd.read_csv('Booking.csv')
df.sample(10)
# Out:
#       Booking_ID  number of adults  number of children  \
# 13843   INN13844                 2                   0
# 520     INN00521                 1                   0
# 10799   INN10800                 2                   0
# 27642   INN27643                 2                   0
# 30041   INN30042                 2                   0
# 4141    INN04142                 2                   1
# 20571   INN20572                 3                   0
# 4380    INN04381                 2                   0
# 4243    INN04244                 2                   0
# 23054   INN23055                 2                   2
#
#        number of weekend nights  number of week nights  type of meal  \
# 13843                         0                      3   Meal Plan 1
# 520                           2                      1   Meal Plan 1
# 10799                         2                      1   Meal Plan 1
# 27642                         1                      0   Meal Plan 1
# 30041                         1                      2   Meal Plan 1
# 4141                          1                      0   Meal Plan 1
# 20571                         2                      1   Meal Plan 1
# 4380                          0                      1  Not Selected
# 4243                          1                      0  Not Selected
# 23054                         1                      2   Meal Plan 1
#
#        car parking space    room type  lead time market segment type  \
# 13843                  0  Room_Type 1        104             Offline
# 520                    0  Room_Type 4          7              Online
# 10799                  0  Room_Type 1         40              Online
# 27642                  0  Room_Type 1          0             Offline
# 30041                  0  Room_Type 1         22              Online
# 4141                   0  Room_Type 1          0              Online
# 20571                  0  Room_Type 4         61             Offline
# 4380                   0  Room_Type 1        113              Online
# 4243                   0  Room_Type 1          0              Online
# 23054                  0  Room_Type 6          1              Online
#
#        repeated  P-C  P-not-C  average price  special requests  \
# 13843         0    0        0          75.00                 0
# 520           0    0        0          85.85                 1
# 10799         0    0        0         112.50                 1
# 27642         0    0        0         111.20                 0
# 30041         0    0        0          76.81                 0
# 4141          0    0        0         127.00                 0
# 20571         0    0        0          90.00                 0
# 4380          0    0        0         108.00                 1
# 4243          0    0        0          90.00                 1
# 23054         0    0        0         211.76                 1
#
#       date of reservation booking status
# 13843           12/3/2017   Not_Canceled
# 520              3/5/2018   Not_Canceled
# 10799           8/28/2018   Not_Canceled
# 27642           9/14/2017   Not_Canceled
# 30041            9/4/2017   Not_Canceled
# 4141            6/26/2018   Not_Canceled
# 20571          11/21/2017   Not_Canceled
# 4380           10/13/2018       Canceled
# 4243             8/1/2018   Not_Canceled
# 23054          10/28/2018   Not_Canceled
